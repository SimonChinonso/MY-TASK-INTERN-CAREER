# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\user\\Downloads\\For Task 2_ Predictive Modeling for Business Forecasting-20240122T104313Z-001.zip")

# %%
df
# Out:
#       Company  Time  Financial Distress      x1        x2       x3       x4  \
# 0           1     1            0.010636  1.2810  0.022934  0.87454  1.21640
# 1           1     2           -0.455970  1.2700  0.006454  0.82067  1.00490
# 2           1     3           -0.325390  1.0529 -0.059379  0.92242  0.72926
# 3           1     4           -0.566570  1.1131 -0.015229  0.85888  0.80974
# 4           2     1            1.357300  1.0623  0.107020  0.81460  0.83593
# ...       ...   ...                 ...     ...       ...      ...      ...
# 3667      422    10            0.438020  2.2605  0.202890  0.16037  0.18588
# 3668      422    11            0.482410  1.9615  0.216440  0.20095  0.21642
# 3669      422    12            0.500770  1.7099  0.207970  0.26136  0.21399
# 3670      422    13            0.611030  1.5590  0.185450  0.30728  0.19307
# 3671      422    14            0.518650  1.6148  0.176760  0.36369  0.18442
#
# ...

# %%
#To display all column
pd.set_option('display.max.columns',None)

# %%
df.head(5)
# Out:
#    Company  Time  Financial Distress      x1        x2       x3       x4  \
# 0        1     1            0.010636  1.2810  0.022934  0.87454  1.21640
# 1        1     2           -0.455970  1.2700  0.006454  0.82067  1.00490
# 2        1     3           -0.325390  1.0529 -0.059379  0.92242  0.72926
# 3        1     4           -0.566570  1.1131 -0.015229  0.85888  0.80974
# 4        2     1            1.357300  1.0623  0.107020  0.81460  0.83593
#
#          x5        x6       x7        x8        x9       x10      x11  \
# 0  0.060940  0.188270  0.52510  0.018854  0.182790  0.006449  0.85822
# 1 -0.014080  0.181040  0.62288  0.006423  0.035991  0.001795  0.85152
# 2  0.020476  0.044865  0.43292 -0.081423 -0.765400 -0.054324  0.89314
# 3  0.076037  0.091033  0.67546 -0.018807 -0.107910 -0.065316  0.89581
# 4  0.199960  0.047800  0.74200  0.128030  0.577250  0.094075  0.81549
#
#        x12       x13      x14     x15       x16     x17       x18       x19  \
# ...

# %%
#TO RENAME THE COLUMN 'Financial Distress'

# %%
data={'Financial Distress':'Financial_Distress'}

# %%
df=df.rename(data, axis='columns')

# %%
df.isnull().sum()
# Out:
# Company               0
# Time                  0
# Financial_Distress    0
# x1                    0
# x2                    0
#                      ..
# x79                   0
# x80                   0
# x81                   0
# x82                   0
# x83                   0
# Length: 86, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3672 entries, 0 to 3671
# Data columns (total 86 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Company             3672 non-null   int64
#  1   Time                3672 non-null   int64
#  2   Financial_Distress  3672 non-null   float64
#  3   x1                  3672 non-null   float64
#  4   x2                  3672 non-null   float64
#  5   x3                  3672 non-null   float64
#  6   x4                  3672 non-null   float64
#  7   x5                  3672 non-null   float64
#  8   x6                  3672 non-null   float64
#  9   x7                  3672 non-null   float64
#  10  x8                  3672 non-null   float64
#  11  x9                  3672 non-null   float64
#  12  x10                 3672 non-null   float64
#  13  x11                 3672 non-null   float64
#  14  x12                 3672 non-null   float64
# ...

# %%
df['Financial_Distress'].max()
# Out:
# 128.4

# %%
df['Financial_Distress'].min()
# Out:
# -8.6317

# %%
#Company 1 business analysis
#BREAKDOWN OF FINANCIAL TRANSACTIONS

# %%
df_C1=df[(df.Company==1)]

# %%
df_C1
# Out:
#    Company  Time  Financial_Distress      x1        x2       x3       x4  \
# 0        1     1            0.010636  1.2810  0.022934  0.87454  1.21640
# 1        1     2           -0.455970  1.2700  0.006454  0.82067  1.00490
# 2        1     3           -0.325390  1.0529 -0.059379  0.92242  0.72926
# 3        1     4           -0.566570  1.1131 -0.015229  0.85888  0.80974
#
#          x5        x6       x7        x8        x9       x10      x11  \
# 0  0.060940  0.188270  0.52510  0.018854  0.182790  0.006449  0.85822
# 1 -0.014080  0.181040  0.62288  0.006423  0.035991  0.001795  0.85152
# 2  0.020476  0.044865  0.43292 -0.081423 -0.765400 -0.054324  0.89314
# 3  0.076037  0.091033  0.67546 -0.018807 -0.107910 -0.065316  0.89581
#
#        x12       x13      x14     x15       x16     x17       x18       x19  \
# 0  2.00580  0.125460   6.9706  4.6512  0.050100  2.1984  0.018265  0.024978
# 1 -0.48644  0.179330   4.5764  3.7521 -0.014011  2.4575  0.027558  0.028804
# ...

# %%
df.describe()
# Out:
#            Company         Time  Financial_Distress           x1           x2  \
# count  3672.000000  3672.000000         3672.000000  3672.000000  3672.000000
# mean    182.084423     7.528322            1.040257     1.387820     0.129706
# std     117.024636     4.064016            2.652227     1.452926     0.120013
# min       1.000000     1.000000           -8.631700     0.075170    -0.258080
# 25%      80.000000     4.000000            0.172275     0.952145     0.048701
# 50%     168.000000     7.000000            0.583805     1.183600     0.107530
# 75%     264.250000    11.000000            1.351750     1.506475     0.188685
# max     422.000000    14.000000          128.400000    51.954000     0.749410
#
#                 x3            x4           x5           x6           x7  \
# count  3672.000000  3.672000e+03  3672.000000  3672.000000  3672.000000
# mean      0.615769  8.681599e-01     0.154949     0.106717     0.784031
# ...

# %%
C1=df_C1[['Time','Financial_Distress']]

# %%
C1
# Out:
#    Time  Financial_Distress
# 0     1            0.010636
# 1     2           -0.455970
# 2     3           -0.325390
# 3     4           -0.566570

# %%
plt.title('Time VS Financial_Distress')
sns.boxplot(data=C1[['Financial_Distress','Time']])
# Out:
# <AxesSubplot:title={'center':'Time VS Financial_Distress'}>

# %%
sns.lmplot(y='Time',x='Financial_Distress', data=C1)

# %%
#Company 2 business analysis
#BREAKDOWN OF FINANCIAL TRANSACTIONS

# %%
df_C2=df[(df.Company==2)]

# %%
df_C2
# Out:
#     Company  Time  Financial_Distress       x1        x2       x3       x4  \
# 4         2     1            1.357300  1.06230  0.107020  0.81460  0.83593
# 5         2     2            0.007188  1.05580  0.081916  0.87949  0.68673
# 6         2     3            1.200200  0.97059  0.076064  0.90677  0.80980
# 7         2     4            2.234800  1.05900  0.130200  0.81811  0.87599
# 8         2     5            1.340500  1.12450  0.147840  0.75871  1.07990
# 9         2     6            2.047400  1.59980  0.262460  0.54615  1.31270
# 10        2     7            2.345900  1.57560  0.262100  0.56448  1.15650
# 11        2     8            2.249900  1.54430  0.240910  0.59073  1.07700
# 12        2     9            2.282600  1.72170  0.215250  0.55229  0.84101
# 13        2    10            1.798200  1.72320  0.208630  0.53398  0.78651
# 14        2    11            2.827700  1.63070  0.186230  0.54772  0.72819
# ...

# %%
df_C2.groupby('Time')['Financial_Distress'].sum().sort_values()
# Out:
# Time
# 2     0.007188
# 3     1.200200
# 5     1.340500
# 1     1.357300
# 10    1.798200
# 6     2.047400
# 14    2.232000
# 4     2.234800
# 8     2.249900
# 9     2.282600
# 7     2.345900
# 13    2.659800
# 11    2.827700
# 12    2.941300
# Name: Financial_Distress, dtype: float64

# %%
df_C2['Financial_Distress'].max()
# Out:
# 2.9413

# %%
df_C2['Financial_Distress'].min()
# Out:
# 0.0071875

# %%
sns.heatmap(df_C2,annot=True)
# Out:
# <AxesSubplot:>

# %%
df_C2=df_C2[['Time','Financial_Distress']].head(10)

# %%
sns.heatmap(df_C2,annot=True)
# Out:
# <AxesSubplot:>

# %%
df_C3=df[(df.Company==3)]

# %%
#BREAKDOWN OF FINANCIAL REPORT/ANALYSIS FOR COMPANY 3

# %%
df_C3.groupby('Time')['Financial_Distress'].sum().sort_values()
# Out:
# Time
# 1   -1.6599
# Name: Financial_Distress, dtype: float64

# %%
df_C3[['Time','Financial_Distress']]
# Out:
#     Time  Financial_Distress
# 18     1             -1.6599

# %%
#BREAKDOWN OF FINANCIAL REPORT/ANALYSIS FOR COMPANY 4

# %%
df_C4=df[(df.Company==4)]

# %%
df_C4
# Out:
#     Company  Time  Financial_Distress       x1        x2       x3       x4  \
# 19        4     1            0.022750  0.83537  0.064310  0.61430  0.49359
# 20        4     2            0.003775  0.93286  0.042339  0.61528  0.49212
# 21        4     3            0.000183  0.93575  0.051198  0.64823  0.63071
# 22        4     4            0.222530  0.92927  0.044282  0.65810  0.62542
# 23        4     5            0.446620  1.08600  0.080419  0.57018  0.66855
# 24        4     6            1.239400  1.19000  0.122380  0.56630  0.78135
# 25        4     7            1.774100  1.82670  0.267580  0.35965  1.02970
# 26        4     8            0.726550  1.72630  0.194110  0.38380  0.86503
# 27        4     9            0.855900  1.54470  0.194380  0.37819  0.77048
# 28        4    10            1.416300  2.12970  0.121510  0.33460  0.81157
# 29        4    11            1.811800  1.51070  0.238170  0.44954  0.87366
# ...

# %%
df_C4.groupby('Time')['Financial_Distress'].sum().sort_values()
# Out:
# Time
# 3     0.000183
# 2     0.003775
# 1     0.022750
# 4     0.222530
# 5     0.446620
# 8     0.726550
# 9     0.855900
# 12    0.861880
# 13    1.096400
# 6     1.239400
# 14    1.277000
# 10    1.416300
# 7     1.774100
# 11    1.811800
# Name: Financial_Distress, dtype: float64

# %%
df_C4.shape
# Out:
# (14, 86)

# %%
df_C4['Financial_Distress'].max()
# Out:
# 1.8118

# %%
df_C4['Financial_Distress'].min()
# Out:
# 0.00018333

# %%
df_C4.plot(x='Time',y='Financial_Distress',grid=True,color='blue',title='Financial distress VS Time')
# Out:
# <AxesSubplot:title={'center':'Financial distress VS Time'}, xlabel='Time'>

# %%
#FINANCIAL ANALYSIS OF COMPANY 5
#BREAKDOWN OF FINANCIAL DISTRESS

# %%
df_C5=df[(df.Company==5)]

# %%
df_C5.shape
# Out:
# (14, 86)

# %%
df_C5['Financial_Distress'].max()
# Out:
# 6.4706

# %%
df_C5['Financial_Distress'].min()
# Out:
# 0.0038233

# %%
sns.lmplot(y='Financial_Distress',x='Time',data=df_C5)

# %%
df_C5.plot(y='Financial_Distress',x='Time',grid=True,color='red',title='Financial distress Vs Time')
# Out:
# <AxesSubplot:title={'center':'Financial distress Vs Time'}, xlabel='Time'>

# %%
#IT CAN BE SEEN THAT THE COMPANY EXPERIENCED WORST FINANCIAL DISTRESS AT TIME 8
#AND LEAST FINANCIAL DISTRESS AT THE FIRST TIME, THAT IS TIME 1

# %% [markdown]
# FINANCIAL ANALYSIS INVOLVING COMPANY 6

# %%
df_C6=df[(df.Company==6)]

# %%
df_C6.shape
# Out:
# (14, 86)

# %%
df_C6['Financial_Distress'].max()
# Out:
# 0.95766

# %%
df_C6['Financial_Distress'].min()
# Out:
# -0.43217

# %%
df_C6
# Out:
#     Company  Time  Financial_Distress       x1        x2       x3       x4  \
# 47        6     1             0.55179  0.75482  0.049331  0.85058  0.74077
# 48        6     2             0.90317  0.70755  0.072754  0.86306  0.89799
# 49        6     3             0.95766  0.73538  0.071925  0.86171  0.80940
# 50        6     4             0.30548  0.58868  0.085379  0.83625  0.79581
# 51        6     5             0.52779  0.69931  0.035085  0.89497  0.68900
# 52        6     6            -0.19589  0.68136  0.049257  0.86638  0.75171
# 53        6     7             0.18757  0.60064  0.012725  0.92407  0.87601
# 54        6     8             0.62713  0.67274  0.031054  0.89910  1.04780
# 55        6     9             0.35803  0.72911  0.045185  0.87972  1.09020
# 56        6    10            -0.30963  0.75708  0.033639  0.87441  1.05620
# 57        6    11            -0.43217  0.77645 -0.038434  0.93345  0.68218
# ...

# %%
df_C6.plot(y='Financial_Distress',x='Time',grid=True,color='green',title='Finacial distress VS Time')
# Out:
# <AxesSubplot:title={'center':'Finacial distress VS Time'}, xlabel='Time'>

# %%
df_C7=df[(df.Company==7)]

# %%
df_C7.shape
# Out:
# (11, 86)

# %%
df_C7['Financial_Distress'].max()
# Out:
# 0.90904

# %%
df_C7['Financial_Distress'].min()
# Out:
# -1.2654

# %%
df_C7.groupby('Financial_Distress')['Time'].sum().sort_values()
# Out:
# Financial_Distress
#  0.89043     1
#  0.15661     2
#  0.25277     3
#  0.86431     4
#  0.90904     5
#  0.52871     6
#  0.19253     7
# -0.43095     8
#  0.28640     9
# -0.44409    10
# -1.26540    11
# Name: Time, dtype: int64

# %%
df_C7.plot(y='Financial_Distress',x='Time',grid=True,color='brown',title='Time Vs Financial distress')
# Out:
# <AxesSubplot:title={'center':'Time Vs Financial distress'}, xlabel='Time'>

# %%
#FROM THE GRAPH WE COULD SEE THAT THE COMPANY EXPERIENCED DIFFICULT FINANCIAL DISTRESS ACROSS
#THE FIRST TIME,FOURTH TIME AND FIFTH TIME, WITH THE WORST BEEN AT THE FIFTH TIME

# %%
df_C8=df[(df.Company==8)]

# %%
df_C8.shape
# Out:
# (14, 86)

# %%
df_C8['Financial_Distress'].max()
# Out:
# 3.7684

# %%
df_C8['Financial_Distress'].min()
# Out:
# 0.30504

# %%
df_C8.groupby('Financial_Distress')['Time'].sum().sort_values()
# Out:
# Financial_Distress
# 0.39830     1
# 0.72890     2
# 1.54780     3
# 3.06130     4
# 3.76840     5
# 0.80947     6
# 0.83493     7
# 0.64581     8
# 0.45568     9
# 0.30504    10
# 1.47720    11
# 1.18140    12
# 0.83918    13
# 0.57721    14
# Name: Time, dtype: int64

# %%
sns.lmplot(x='Time',y='Financial_Distress',data=df_C8)

# %%
df_C8.plot(y='Financial_Distress',x='Time',grid=True,color='orange',title='Time VS Financial distress')
# Out:
# <AxesSubplot:title={'center':'Time VS Financial distress'}, xlabel='Time'>

# %%
#FOR THIS COMPANY HER FINANCIAL DISTRESS WAS WORST AT THE FIFTH TIME

# %%
df_C9=df[(df.Company==9)]

# %%
df_C9['Financial_Distress'].max()
# Out:
# 2.0248

# %%
df_C9['Financial_Distress'].min()
# Out:
# -0.38026

# %%
df_C9.groupby('Financial_Distress')['Time'].sum().sort_values()
# Out:
# Financial_Distress
#  0.043433     1
#  0.088750     2
#  0.083333     3
#  0.250780     4
#  0.022139     5
# -0.380260     6
#  0.076062     7
#  0.246200     8
#  0.065554     9
#  0.300250    10
#  2.024800    11
#  0.783200    12
#  0.559250    13
#  0.284190    14
# Name: Time, dtype: int64

# %%
df_C9.shape
# Out:
# (14, 86)

# %%
df_C9.plot(y='Financial_Distress',x='Time',grid=True,color='black',title='Financial distress VS Time')
# Out:
# <AxesSubplot:title={'center':'Financial distress VS Time'}, xlabel='Time'>

# %%
df_C10=df[(df.Company==10)]

# %%
df_C10.shape
# Out:
# (14, 86)

# %%
df_C10['Financial_Distress'].max()
# Out:
# 1.1553

# %%
df_C10['Financial_Distress'].min()
# Out:
# 5.95e-05

# %%
df_C10.groupby('Financial_Distress')['Time'].sum().sort_values()
# Out:
# Financial_Distress
# 0.000964     1
# 0.000060     2
# 0.000070     3
# 0.000205     4
# 0.000171     5
# 0.000250     6
# 0.000108     7
# 0.446800     8
# 0.454610     9
# 0.451940    10
# 1.017300    11
# 1.155300    12
# 0.310120    13
# 0.216870    14
# Name: Time, dtype: int64

# %%
df_C10.plot(y='Financial_Distress',x='Time',grid=True,color='blue',title='Financial distress VS Time')
# Out:
# <AxesSubplot:title={'center':'Financial distress VS Time'}, xlabel='Time'>

# %%
#FROM THE VIZUALIZATION IT COULD BE SEEN THAT FROM FIRST TO THE SEVENTH TIME
#THERE WERE RELATIVELY NO SIGNIFICANT OR LEAST FINANCIAL DISTRESS, 
#WHILE THE ELEVENTH TIME HAD THE HIGHEST FINANCIAL DISTRESS

# %%
#FINANCIAL ANALYSIS INVOLVING COMPANY 11

# %%
df_C11=df[(df.Company==11)]

# %%
df_C11
# Out:
#      Company  Time  Financial_Distress       x1        x2       x3       x4  \
# 114       11     1            0.453630  0.68880  0.100870  0.66560  0.64705
# 115       11     2            0.631800  0.69080  0.092661  0.67728  0.67327
# 116       11     3           -0.312750  0.74702  0.110360  0.58811  0.56551
# 117       11     4           -0.317520  0.50287 -0.041789  0.72860  0.37339
# 118       11     5           -0.113150  0.52596  0.003629  0.76141  0.42338
# 119       11     6            0.185200  0.41398  0.032967  0.73549  0.44728
# 120       11     7            0.015037  0.63040  0.085589  0.65866  0.54933
# 121       11     8           -0.310030  0.57318 -0.041006  0.68858  0.59575
# 122       11     9           -0.801590  0.54940 -0.093647  0.78922  0.55957
#
#            x5       x6       x7        x8        x9       x10      x11  \
# 114  0.112920 -0.18517  0.44691  0.155890  0.301640  0.079890  0.40986
# ...

# %%
df_C11['Financial_Distress'].max()
# Out:
# 0.6318

# %%
df_C11['Financial_Distress'].min()
# Out:
# -0.80159

# %%
a=df_C11[['Financial_Distress','Time']]

# %%
a.plot(y='Financial_Distress',x='Time',grid=True,color='purple',title='Financial_distress VS Time')
# Out:
# <AxesSubplot:title={'center':'Financial_distress VS Time'}, xlabel='Time'>

# %%
#FROM THE GRAPH WE CAN SEE THAT THE COMPANY HAD THE WORST FINANCIAL DISTRESS AT TIME 1
#WHILE IT HAD THE LEAST FINANCIAL DISTRESS AT THE FIRST TIME, TIME 1

# %%
df_C12=df[(df.Company==12)]

# %%
df_C12
# Out:
#      Company  Time  Financial_Distress      x1        x2       x3       x4  \
# 123       12     1            -0.66786  1.1953  0.060823  0.77593  0.57977
#
#            x5       x6       x7       x8       x9      x10      x11     x12  \
# 123  0.065788  0.14242  0.45965  0.10491  0.27145  0.10726  0.87179  4.1206
#
#          x13    x14     x15      x16     x17       x18       x19       x20  \
# 123  0.22407  3.463  2.1841  0.11347  2.2876  0.015306  0.027538  0.020985
#
#          x21     x22      x23      x24     x25     x26     x27      x28  \
# 123  0.66504  7.5364  0.19227  0.72937  1135.7  13.878  4.0709  0.31586
#
#           x29      x30    x31      x32      x33     x34     x35       x36  \
# 123  0.046568  0.33525  64.58  0.57825  0.93999  2.8321  164.82  0.069769
#
#          x37     x38      x39       x40     x41     x42     x43      x44  \
# 123  0.20783  0.0264  0.34433  0.076929  2.5875  0.2431  2.9126  0.79064
#
# ...

# %%
df_C13=df[(df.Company==13)]

# %%
df_C13.shape
# Out:
# (2, 86)

# %%
df_C13[['Financial_Distress','Time']]
# Out:
#      Financial_Distress  Time
# 124           -0.081598     1
# 125           -0.893830     2

# %%
#FOR COMPANY 14 FINANCIAL DISTRESS OVER TIME

# %%
df_C14=df[(df.Company==14)]

# %%
df_C14[['Financial_Distress','Time']]
# Out:
#      Financial_Distress  Time
# 126             0.42800     1
# 127             0.39178     2
# 128             0.94842     3
# 129             3.04530     4
# 130             2.65290     5
# 131             2.12660     6
# 132             1.13940     7
# 133            -0.66968     8

# %%
df_C14.plot(y='Financial_Distress',x='Time',grid=True,color='red',title='Financial Distress VS Time')
# Out:
# <AxesSubplot:title={'center':'Financial Distress VS Time'}, xlabel='Time'>

# %%
#The company started having rise in financial distress from TIME 2, and it rose to the peak at TIME 4
#And the financial distress immediately began to decline along that path each passing time
#It declined to the least financial distress at TIME 8

# %%
df_C15=df[(df.Company==15)]

# %%
df_C15
# Out:
#      Company  Time  Financial_Distress       x1        x2       x3       x4  \
# 134       15     1            -0.12797  2.44660  0.119150  0.38647  1.00820
# 135       15     2             0.28768  1.22930  0.000142  0.60446  0.86235
# 136       15     3            -0.15722  1.93480  0.032604  0.65715  1.04840
# 137       15     4             1.16680  1.17840  0.034128  0.78997  0.69364
# 138       15     5             2.55930  0.69336  0.128490  0.73143  0.87679
# 139       15     6            -2.70310  0.98949  0.080388  0.76228  0.69112
#
#            x5        x6       x7        x8        x9       x10      x11  \
# 134  0.112800  0.423030  1.67670  0.118180  0.194210  0.103430  0.71546
# 135 -0.018235  0.123820  0.78265  0.000165  0.000360 -0.012781  0.66380
# 136  0.056658  0.339670  1.16290  0.031099  0.095095  0.022539  0.70304
# 137  0.066784  0.067627  0.80553  0.049201  0.162490 -0.008400  0.44662
# 138  0.203650 -0.138390  0.24313  0.146540  0.478410  0.059630  0.31293
# ...

# %%
df_C15[['Financial_Distress','Time']]
# Out:
#      Financial_Distress  Time
# 134            -0.12797     1
# 135             0.28768     2
# 136            -0.15722     3
# 137             1.16680     4
# 138             2.55930     5
# 139            -2.70310     6

# %%
df_C15.plot(y='Financial_Distress',x='Time',grid=True,color='brown',title='Financial_Distress VS Time')
# Out:
# <AxesSubplot:title={'center':'Financial_Distress VS Time'}, xlabel='Time'>

# %%
#It could be oberved that the Company had her worst financial distress at Time 5

# %%
df_C16=df[(df.Company==16)]

# %%
df_C16
# Out:
#      Company  Time  Financial_Distress       x1        x2       x3       x4  \
# 140       16     1            0.105900  1.80870  0.152810  0.51990  1.27550
# 141       16     2            0.480280  1.03850  0.045462  0.84047  0.63739
# 142       16     3            0.088538  0.70624  0.018303  0.89407  0.52226
# 143       16     4            0.032712  0.62093  0.008059  0.88966  0.37295
# 144       16     5           -3.657400  0.64375  0.002443  0.91748  0.41045
#
#            x5        x6       x7        x8        x9       x10      x11  \
# 140  0.122260  0.348010  0.77240  0.119800  0.318290  0.154630  0.77836
# 141  0.062467  0.016744  0.32740  0.071325  0.284970  0.007977  0.45111
# 142  0.022417 -0.142100  0.26542  0.035045  0.172770  0.020415  0.34162
# 143  0.006268 -0.230390  0.19224  0.021608  0.073034  0.008654  0.37739
# 144  0.021599 -0.236520  0.23853  0.005951  0.029602  0.002320  0.42740
#
# ...

# %%
df_C16.plot(y='Financial_Distress',x='Time',grid=True,color='blue',title='Financial distress VS Time')
# Out:
# <AxesSubplot:title={'center':'Financial distress VS Time'}, xlabel='Time'>

# %%
df_C17=df[(df.Company==17)]

# %%
df_C17
# Out:
#      Company  Time  Financial_Distress      x1        x2       x3       x4  \
# 145       17     1             1.36990  1.5896  0.188210  0.51817  0.77090
# 146       17     2             0.87835  1.5389  0.179900  0.54174  0.88064
# 147       17     3             1.07350  1.5327  0.169410  0.55304  0.89325
# 148       17     4             1.22370  1.4160  0.133950  0.62147  0.90610
# 149       17     5             0.64233  1.4175  0.124730  0.63926  0.92697
# 150       17     6             0.58162  1.3188  0.100700  0.69605  0.94273
# 151       17     7            -0.44527  1.2287  0.059073  0.75473  0.85993
# 152       17     8            -0.49922  1.0208 -0.123450  0.88382  0.80272
# 153       17     9            -1.99710  1.1692 -0.001216  0.89659  1.09280
#
#            x5        x6       x7        x8        x9       x10      x11  \
# 145  0.213330  0.274970  0.60877  0.244140  0.390620  0.202930  0.74134
# 146  0.219250  0.263130  0.53065  0.204280  0.392570  0.196140  0.75137
# ...

# %%
df_C17.plot(y='Financial_Distress',x='Time',grid=True,color='red',title='Financial_Distress VS Time')
# Out:
# <AxesSubplot:title={'center':'Financial_Distress VS Time'}, xlabel='Time'>

# %%
df_C18=df[(df.Company==18)]

# %%
df_C18.shape
# Out:
# (6, 86)

# %%
df_C18.plot(y='Financial_Distress',x='Time',grid=True,color='grey',title='Financial_distress VS Time')
# Out:
# <AxesSubplot:title={'center':'Financial_distress VS Time'}, xlabel='Time'>

# %%
df_C19=df[(df.Company==19)]

# %%
df_C19.shape
# Out:
# (3, 86)

# %%
df_C19
# Out:
#      Company  Time  Financial_Distress       x1        x2       x3       x4  \
# 160       19     1              0.0000  0.84654  0.047250  0.93078  1.07250
# 161       19     2             -0.1888  0.86145  0.054045  0.87655  1.50860
# 162       19     3             -1.7971  0.87458 -0.000292  0.94364  0.73338
#
#            x5       x6       x7        x8        x9       x10      x11  \
# 160  0.069943 -0.13793  0.33007  0.044057  0.682650  0.000000  0.76089
# 161  0.091859 -0.11640  0.56292  0.035825  0.437780  0.000000  0.72374
# 162 -0.066203 -0.11734  0.50443 -0.000398 -0.005184 -0.012058  0.81829
#
#         x12       x13      x14     x15       x16     x17       x18       x19  \
# 160  2.3999  0.069216  13.4480  5.9954  0.065217  2.5962  0.030105  0.027175
# 161  1.6493  0.123450   7.1003  5.5958  0.060892  6.6176  0.058673  0.036919
# 162 -1.1239  0.056364  16.7420  3.7368 -0.090271  2.3594  0.062018  0.080316
#
# ...

# %%
df_C20=df[(df.Company==20)]

# %%
df_C20.shape
# Out:
# (14, 86)

# %%
df_C20[['Financial_Distress','Time']]
# Out:
#      Financial_Distress  Time
# 163            0.000000     1
# 164            0.000000     2
# 165            0.567090     3
# 166            2.110200     4
# 167            2.651500     5
# 168            4.758400     6
# 169            2.368700     7
# 170            2.026000     8
# 171            0.810710     9
# 172            0.491670    10
# 173            1.289300    11
# 174            0.585650    12
# 175            0.069254    13
# 176            0.149230    14

# %%
df_C20.plot(y='Financial_Distress',x='Time',grid=True,color='yellow',title='Financial_Distress VS Time')
# Out:
# <AxesSubplot:title={'center':'Financial_Distress VS Time'}, xlabel='Time'>

# %%
df_C21=df[(df.Company==21)]

# %%
df_C12.shape
# Out:
# (1, 86)

# %%
df_C22=df[(df.Company==22)]

# %%
df_C22.shape
# Out:
# (14, 86)

# %%
df_C22.plot(y='Financial_Distress',x='Time',grid=True,color='black',title='Financial_Distress VS Time')
# Out:
# <AxesSubplot:title={'center':'Financial_Distress VS Time'}, xlabel='Time'>

# %%
df_C23=df[(df.Company==23)]

# %%
df_C23.shape
# Out:
# (14, 86)

# %%
df_C23.plot(y='Financial_Distress',x='Time',grid=True,color='red',title='Financial_Distress VS Time')
# Out:
# <AxesSubplot:title={'center':'Financial_Distress VS Time'}, xlabel='Time'>

# %%
df_C24=df[(df.Company==24)]

# %%
df_C24.shape
# Out:
# (14, 86)

# %%
df_C24.plot(y='Financial_Distress',x='Time',grid=True,color='orange',title='Financial_Distress VS Time')
# Out:
# <AxesSubplot:title={'center':'Financial_Distress VS Time'}, xlabel='Time'>

# %%
#ANALYzING TOP 10 COMPANIES WITH WORST FINANCIAL DISTRESS

# %%
a=df.groupby('Company')['Financial_Distress'].sum().sort_values(ascending=False)

# %%
a.head(10)
# Out:
# Company
# 282    131.252450
# 77      67.023090
# 233     60.440645
# 30      56.137863
# 25      55.042430
# 360     53.482107
# 212     52.725435
# 421     50.177800
# 367     49.052660
# 55      47.534800
# Name: Financial_Distress, dtype: float64

# %%
df_C282=df[(df.Company==282)]

# %%
df_C282.plot(y='Financial_Distress',x='Time',grid=True,color='blue',title='Company282_Financial_Distress VS Time')
# Out:
# <AxesSubplot:title={'center':'Company282_Financial_Distress VS Time'}, xlabel='Time'>

# %%
df_C77=df[(df.Company==77)]

# %%
df_C77[['Company','Time']]
# Out:
#      Company  Time
# 874       77     1
# 875       77     2
# 876       77     3
# 877       77     4
# 878       77     5
# 879       77     6
# 880       77     7
# 881       77     8
# 882       77     9
# 883       77    10
# 884       77    11
# 885       77    12
# 886       77    13
# 887       77    14

# %%
df_C77.plot(y='Financial_Distress',x='Time',grid=True,color='red',title='Company77_Financial_Distress VS Time')
# Out:
# <AxesSubplot:title={'center':'Company77_Financial_Distress VS Time'}, xlabel='Time'>

# %%
df_C233=df[(df.Company==233)]

# %%
df_C233.plot(y='Financial_Distress',x='Time',grid=True,color='yellow',title='Company233_Financial_Distress VS Time')
# Out:
# <AxesSubplot:title={'center':'Company233_Financial_Distress VS Time'}, xlabel='Time'>

# %%
df_C30=df[(df.Company==30)]

# %%
df_C30.plot(y='Financial_Distress',x='Time',grid=True,color='green',title='Company30_Financial_Distress VS Time')
# Out:
# <AxesSubplot:title={'center':'Company30_Financial_Distress VS Time'}, xlabel='Time'>

# %%
df_C25=df[(df.Company==25)]

# %%
df_C25.plot(y='Financial_Distress',x='Time',grid=True,color='red',title='Company25_Financial_Distress VS Time')
# Out:
# <AxesSubplot:title={'center':'Company25_Financial_Distress VS Time'}, xlabel='Time'>

# %%
df_C360=df[(df.Company==360)]

# %%
df_C360.plot(y='Financial_Distress',x='Time',grid=True,color='blue',title='Company360_Financial_Distress VS Time')
# Out:
# <AxesSubplot:title={'center':'Company360_Financial_Distress VS Time'}, xlabel='Time'>

# %%
df_C212=df[(df.Company==212)]

# %%
df_C212.plot(y='Financial_Distress',x='Time',grid=True,color='yellow',title='Company212_Financial_Distress VS Time')
# Out:
# <AxesSubplot:title={'center':'Company212_Financial_Distress VS Time'}, xlabel='Time'>

# %%
df_C421=df[(df.Company==421)]

# %%
df_C421.plot(y='Financial_Distress',x='Time',grid=True,color='green',title='Company421_Financial_Distress VS Time')
# Out:
# <AxesSubplot:title={'center':'Company421_Financial_Distress VS Time'}, xlabel='Time'>

# %%
df_C367=df[(df.Company==367)]

# %%
df_C367
# Out:
#       Company  Time  Financial_Distress       x1       x2       x3       x4  \
# 3317      367     2             0.68735  1.69660  0.48177  0.46113  0.55432
# 3318      367     3             0.93491  1.27650  0.42302  0.52467  0.52986
# 3319      367     4             2.83500  0.95081  0.36529  0.62670  0.69650
# 3320      367     5             3.79730  2.04050  0.36562  0.31843  0.95540
# 3321      367     6             4.42920  1.69870  0.27595  0.43903  0.66576
# 3322      367     7             7.90350  1.43860  0.19755  0.54669  0.66314
# 3323      367     8             7.44310  1.24400  0.29385  0.52336  0.39775
# 3324      367     9             2.10790  0.86502  0.21353  0.61464  0.24983
# 3325      367    10             4.13680  0.88100  0.26319  0.56131  0.15869
# 3326      367    11             5.76090  1.23090  0.32404  0.49067  0.18973
# 3327      367    12             2.18600  1.13320  0.31006  0.45790  0.32507
# ...

# %%
df_C367.plot(y='Financial_Distress',x='Time',grid=True,color='blue',title='Company367_Financial_Distress VS Time')
# Out:
# <AxesSubplot:title={'center':'Company367_Financial_Distress VS Time'}, xlabel='Time'>

# %%
df_C55=df[(df.Company==55)]

# %%
df_C55.shape
# Out:
# (14, 86)

# %%
df_C55.plot(y='Financial_Distress',x='Time',grid=True,color='red',title='Company55_Financial_Distress VS Time')
# Out:
# <AxesSubplot:title={'center':'Company55_Financial_Distress VS Time'}, xlabel='Time'>

# %%
#TOP 10 COMPANIES WITH LEAST FINANCIAL DISTRESS

# %%
b=df.groupby('Company')['Financial_Distress'].sum().sort_values()

# %%
b.head(10)
# Out:
# Company
# 89    -5.683800
# 275   -4.382900
# 355   -4.344770
# 180   -4.072408
# 37    -3.088209
# 16    -2.949970
# 351   -2.507310
# 35    -2.503641
# 36    -2.500657
# 44    -2.254428
# Name: Financial_Distress, dtype: float64

# %%
df_C89=df[(df.Company==89)]

# %%
df_C89.shape
# Out:
# (1, 86)

# %%
df_C275=df[(df.Company==275)]

# %%
df_C275.shape
# Out:
# (1, 86)

# %%
df_C355=df[(df.Company==355)]

# %%
df_C355.shape
# Out:
# (4, 86)

# %%
df_C355.plot(y='Financial_Distress',x='Time',grid=True,color='yellow',title='Company355_Financial_Distress VS Time')
# Out:
# <AxesSubplot:title={'center':'Company355_Financial_Distress VS Time'}, xlabel='Time'>

# %%
df_C180=df[(df.Company==180)]

# %%
df_C180.shape
# Out:
# (5, 86)

# %%
df_C180.plot(y='Financial_Distress',x='Time',grid=True,color='red',title='Company180_Financial_Distress VS Time')
# Out:
# <AxesSubplot:title={'center':'Company180_Financial_Distress VS Time'}, xlabel='Time'>

# %%
df_C37=df[(df.Company==37)]

# %%
df_C37.shape
# Out:
# (10, 86)

# %%
df_C37.plot(y='Financial_Distress',x='Time',grid=True,color='blue',title='Company37_Financial_Distress VS Time')
# Out:
# <AxesSubplot:title={'center':'Company37_Financial_Distress VS Time'}, xlabel='Time'>

# %%
df_C16=df[(df.Company==16)]

# %%
df_C16.shape
# Out:
# (5, 86)

# %%
df_C16.plot(y='Financial_Distress',x='Time',grid=True,color='green',title='Company16_Financial_Distress VS Time')
# Out:
# <AxesSubplot:title={'center':'Company16_Financial_Distress VS Time'}, xlabel='Time'>

# %%
df_C351=df[(df.Company==351)]

# %%
df_C351.shape
# Out:
# (7, 86)

# %%
df_C351.plot(y='Financial_Distress',x='Time',grid=True,color='black',title='Company351_Financial_Distress VS Time')
# Out:
# <AxesSubplot:title={'center':'Company351_Financial_Distress VS Time'}, xlabel='Time'>

# %%
df_C35=df[(df.Company==35)]

# %%
df_C35.shape
# Out:
# (9, 86)

# %%
df_C35.plot(y='Financial_Distress',x='Time',gid=True,color='yellow',title='Company35_Financial_Distress VS Time')
# Out:
# <AxesSubplot:title={'center':'Company35_Financial_Distress VS Time'}, xlabel='Time'>

# %%
df_C36=df[(df.Company==36)]

# %%
df_C36.shape
# Out:
# (9, 86)

# %%
df_C36.plot(y='Financial_Distress',x='Time',grid=True,color='red',title='Company36_Financial_Distress VS Time')
# Out:
# <AxesSubplot:title={'center':'Company36_Financial_Distress VS Time'}, xlabel='Time'>

# %%
df_C44=df[(df.Company==44)]

# %%
df_C44.shape
# Out:
# (9, 86)

# %%
df_C44.plot(y='Financial_Distress',x='Time',grid=True,color='blue',title='Company44_Financial_Distress VS Time')
# Out:
# <AxesSubplot:title={'center':'Company44_Financial_Distress VS Time'}, xlabel='Time'>
